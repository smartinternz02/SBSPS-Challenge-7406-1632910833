# %% [markdown]
# IMPORTING DATA

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
data=pd.read_csv("Sanitation.csv")
label=[]
for row in data.ULB:
    label.append(row)
label
data
# Out:
#               ULB  Public Toilets  Community Toilets  She Toilets  \
# 0        Adilabad             8.0                NaN          NaN
# 1   Andol-Jogipet             NaN                NaN          NaN
# 2          Armoor             4.0                NaN          NaN
# 3       Atchampet             NaN                NaN          NaN
# 4       Badangpet             NaN                NaN          NaN
# ..            ...             ...                ...          ...
# 67      Vikarabad             3.0                NaN          NaN
# 68     Wanaparthy             NaN                NaN          NaN
# 69       Warangal             1.0                NaN          NaN
# 70       Yellandu             NaN                NaN          NaN
# 71     Zaheerabad             NaN                NaN          NaN
#
#     ODF Declared Wards  ODF Non Declared Wards  \
# 0                   36                       0
# 1                   10                      10
# ...

# %% [markdown]
# PIE CHART

# %%
textprops={"fontsize":15}
fig=plt.pie(data.Garbagelifted,labels=label,radius=20,textprops=textprops,autopct = "%0.2f%%")
plt.title('waste')
plt.legend()
plt.show(fig)

# %%
LINE PLOT

# %%
fig1=plt.plot(data.Garbagegeneration,label,color='r')
fig1=plt.plot(data.Garbagelifted,label,color='g')
plt.rc('lines', linewidth=2, linestyle='-', marker='*')
plt.rcParams["figure.figsize"] = (50, 30)
plt.xlabel('Garbage Generation')
plt.ylabel('Garbage Lifted')
plt.grid(fig1)

# %%
AREA PLOT

# %%
data.plot.area(x='ULB')
# Out:
# <AxesSubplot:xlabel='ULB'>

# %%
df=pd.DataFrame(columns=['Difference'])
df['Difference']=data['Garbagegeneration']-data['Garbagelifted']
df
# Out:
#     Difference
# 0          2.0
# 1          0.8
# 2          2.0
# 3          0.0
# 4          0.0
# ..         ...
# 67         0.0
# 68         0.0
# 69         0.0
# 70         2.0
# 71         0.0
#
# [72 rows x 1 columns]

# %% [markdown]
# BAR PLOT

# %%
data.plot.bar(x='ULB',y='Garbagegeneration',color='red',stacked=True,subplots=False)
data.plot.bar(x='ULB',y='Garbagelifted',color='green',stacked=True,subplots=False)
# Out:
# <AxesSubplot:xlabel='ULB'>

# %% [markdown]
# DIFFERENCE OF BARPLOTS

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>
